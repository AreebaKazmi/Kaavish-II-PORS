# %%
# from google.colab import drive
# drive.mount('/content/drive')
#
import os
# os.chdir('/content/drive/My Drive/Deep Fashion Retrieval/deep-fashion-retrieval')

# %%
import os
# from config import *
# Out:
# 11

# %%
# from data import Fashion_inshop
# dataset = Fashion_inshop(type="test_query")
# print(dataset.test_gallery_len)

from feaure_extractor import get_inshop_test_db
query_feat_dict, (deep_feats, color_feats, labels) = get_inshop_test_db()

# from in_shop_eval import load_inshop_test_db
# inshop_test_db_dict = load_inshop_test_db()

# length = len(dataset)
# deep_feats, color_feats, labels = inshop_test_db_dict['test_query']
# deep_feats, color_feats, labels = deep_feats[-length:], color_feats[-length:], labels[-length:]
# feat_dict = {labels[i]: (deep_feats[i], color_feats[i]) for i in range(len(labels))}
# print(f'feat_dict: {feat_dict}')

# from retrieval import get_deep_color_top_n
# for iter_id, (img, img_path) in enumerate(dataset):
#     get_deep_color_top_n(img_path, deep_feats, color_feats, labels, retrieval_top_n)

# import numpy as np
# retrieval_top_n=(1, 10, 20, 50)
# result_arr = np.zeros((dataset.test_query_len, len(retrieval_top_n)))
#
# a = [1,2,3,4]
# if 2 in a:
#     result_arr[0, 1:] = 1
#
# for i,j in zip(a, result_arr.sum(axis=0)):
#     print(i,j)

# %%
# Creates feature db. Run this every time you load a new model.
! python feature_extractor.py --scrapped
# Out:
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/torchvision/transforms/transforms.py:210: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# Loading model freeze=False/lr=0.001/29_epochs
# Extracting features from scrapped dataset.
# dump function called with custom: True
# all_list: ['/home/ma02526/ResNet/base/scrapped/jdot/0a0696c7b8f9c84c97e916cafac11a491b2f1230.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/0ad8953502aa99550cb26556560eb64fface5db7.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/0bbbcba93098a2a8cea59e3cc531685efc30e2ed.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/0d615c7c56e76fdf84e9b48191240755f4cc3804.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/0dbc2f21435c0e1cfc8b3f883d6c47df464e4e5b.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/0df6793aa25b13e2e51b70712dc6f74c5315159f.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/0ec9cddb6910c4bba113679432cf48c598b77969.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/1b84c450431041a7d85b827c3c2fb5467cb504a6.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/1d1e47e53b360bedb46a49382222ca1b693dc24e.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/1d91c48fa8f899a570db6904b7adc5b463eb85b5.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/2aa032fee6c7c26c2a9ee33e485a1ed073e770e5.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/2bf319dac8f05b775f651cc602b733134610bb37.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/2f1a88faa0112ca51d8f320b935f6bfc9c05829d.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/4e359672c99f2c6da4f1c699e6eaa2f4a7066597.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/5b37b203adf3a84b5958903f522884fa88d5108b.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/5be74da0bb2d289551281d7c09155d5fee539861.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/5d9a868a9baae4d4f27a695cf86063fc40723850.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/5df704753cc1fc6491d928eca11b90e008d57b04.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/5edd3e7faf56ad312cbd88fd65a1d1afd716fcaa.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/5f17121cb04a29e25151a11dc11e48b2c9959490.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/6d2c11645af7ae63c142835ab873cbdb3a3862f0.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/7a1da94a60aef69d1ed03ae9c8a81218d32302f5.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/7a33bc8f7f3556a1bb6171076b2218bf78ed40c2.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/7b40d18f09957b653482fc7fc1bb7dbb141d8b34.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/7ece9db9dca2b201438480bede74ba6c324292ce.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/7fa8684f2970a1aa0b57b4cffd93bc5cb42fbc36.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/8c3c1d6e07379f990da69b1063b670537e665fb6.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/8d6ef326210b65b5155056afd74934959ed6b120.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/8dfe1fea818660ff809f7c2acd8abfcae2a84e70.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/8f07dae2d1e44f6d58bbed1b1423de429b0fcf60.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/8f25fb1d84a035ef7851b4fc6dbeea957d13b3dd.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/9af8e094e8a01be72b683e11d71eb95cd643a500.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/9c9e09c8b2c290a6febb17966a0bef318858ca58.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/9d3dbef0cc0269b21ba7c7b2e9721c3280369537.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/9d7209a5aa1747f3c82a939ec039244bc608c67d.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/013fb1d678abfcc571e0d4d701e82cec37b0ac33.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/15eab078067b59d82b0127e7519f615068c4d016.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/17f17ef0df4a07af72662372cf591ef0a577bd18.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/24a84da1d89f9006cec35f6256bb4ae167f638ee.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/35be4150267ede558c33ba8f28345c957fc7b370.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/37cb9fd6989dd260f4031139a864a22c11b9874c.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/37e0f337d75f6cc6d41d88e4ac82df1eca3cc1cb.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/40bed6681d23182795ba828e0e78e4f5894839e9.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/41f868814966f695a64517d3ffe1dd5cf23ebf3a.jpg', '/home/ma02526/ResNet/base/scrapped/jdot/43c86ac859d48705d79a29f0ca6a2275e607c4f2.jpg', '/home/ma02526/ResNet/base/sc ...
# 0 / 400
# Dumped to custom_all_class.npy, custom_all_feat.npy, custom_all_color_feat.npy and custom_all_feat.list.

# %%
from retrieval import *
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

example = "hu_men/IMG_20200120_145822.jpg"

extractor = load_test_model()

deep_feats, color_feats, labels = load_feat_db(custom=True)

f = dump_single_feature(example, extractor, custom=True)

result = naive_query(f, deep_feats, color_feats, labels, 5)

print("Naive query result:", result)
visualize(example, result)
# Out:
# Loading model...
# Loading model freeze=False/lr=0.001/29_epochs
# Loading model Done. Time: 0.441 sec
# Loading feature database...
# Loading feature database Done. Time: 0.001 sec
# Extracting image feature...
# Extracting image feature Done. Time: 0.214 sec
# Doing naive query...
# Doing naive query Done. Time: 0.002 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/elo/e595ceff5581561de6069a462db737a6702da0f5.jpg', -4.168832929797235), ('/home/ma02526/ResNet/base/scrapped/furor/77906fcf947f40b7e79769de4fd9086f60cae4ba.jpg', -4.29264045424013), ('/home/ma02526/ResNet/base/scrapped/elo/8dd435f4cb52704cc676519512a5c3868f4aec83.jpg', -4.298943993143718), ('/home/ma02526/ResNet/base/scrapped/furor/ee1eb2fa967b8787b8a96b234cd95a0676dfe48c.jpg', -4.334972853662564), ('/home/ma02526/ResNet/base/scrapped/furor/75dbe92ab170f8c4c9ecbd169bea2c5f5dbd83d9.jpg', -4.352850080939946)]

# %%
from retrieval import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.rcParams['figure.figsize'] = [10, 5]

examples = ["hu_men/IMG_20200120_145822.jpg", #- talha's beige round neck tshirt
            "hu_men/IMG_20200130_152400.jpg", #- saad saleem's brown leather jacket
            "hu_men/IMG_20200120_145759.jpg", #- talha's black skinny jeans
            "hu_men/IMG_20200130_123311.jpg", #- burhan's dark blue checked shirt
            "scrapped/jdot/2f1a88faa0112ca51d8f320b935f6bfc9c05829d.jpg",
            "scrapped/jdot/8dfe1fea818660ff809f7c2acd8abfcae2a84e70.jpg", #- mustard yellow shalwar kameez
            "scrapped/jdot/9d7209a5aa1747f3c82a939ec039244bc608c67d.jpg"]

extractor = load_test_model()

deep_feats, color_feats, labels = load_feat_db(custom=True)

for example in examples:
    f = dump_single_feature(example, extractor, custom=True)

    if any(list(map(lambda x: x is None, f))):
        print("Input feature is None")
        exit()

    result = naive_query(f, deep_feats, color_feats, labels, 5)

    print("Naive query result:", result)
    visualize(example, result)
# Out:
# Loading model...
# Loading model freeze=False/lr=0.001/29_epochs
# Loading model Done. Time: 0.426 sec
# Loading feature database...
# Loading feature database Done. Time: 0.001 sec
# Extracting image feature...
# Extracting image feature Done. Time: 0.208 sec
# Doing naive query...
# Doing naive query Done. Time: 0.002 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/elo/e595ceff5581561de6069a462db737a6702da0f5.jpg', -4.168832929797235), ('/home/ma02526/ResNet/base/scrapped/furor/77906fcf947f40b7e79769de4fd9086f60cae4ba.jpg', -4.29264045424013), ('/home/ma02526/ResNet/base/scrapped/elo/8dd435f4cb52704cc676519512a5c3868f4aec83.jpg', -4.298943993143718), ('/home/ma02526/ResNet/base/scrapped/furor/ee1eb2fa967b8787b8a96b234cd95a0676dfe48c.jpg', -4.334972853662564), ('/home/ma02526/ResNet/base/scrapped/furor/75dbe92ab170f8c4c9ecbd169bea2c5f5dbd83d9.jpg', -4.352850080939946)]
# Extracting image feature...
# Extracting image feature Done. Time: 0.174 sec
# Doing naive query...
# Doing naive query Done. Time: 0.001 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/furor/8cf93e26c16dc39b873c16efdb109cce416be9f3.jpg', -4.95686575698596), ('/home/ma02526/ResNet/base/scrapped/elo/207cd38335916b4f006332342901e45f3441ac29.jpg', -5.713563147346128), ('/home/ma02526/ResNet/base/scrapped/furor/cf5c25975980afee5ec3c460ac42746a042725af.jpg', -5.862417108513879), ('/home/ma02526/ResNet/base/scrapped/furor/d39bbba57e7e9e42c9c9d8b4beec19233528d76f.jpg', -6.178292590332936), ('/home/ma02526/ResNet/base/scrapped/zellbury/ea5d2851d39787a10ec3306b54f265319e5c5b4a.jpg', -6.595072777674541)]
# Extracting image feature...
# Extracting image feature Done. Time: 0.169 sec
# Doing naive query...
# Doing naive query Done. Time: 0.001 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/furor/73789a68d2efa8641dde3dabfee71ffa95b23e13.jpg', -5.132003741192364), ('/home/ma02526/ResNet/base/scrapped/furor/e58685ad19decba1a64a021ddd61c958f0d37f3e.jpg', -5.145450837892745), ('/home/ma02526/ResNet/base/scrapped/furor/91e978f68528d07f7198e4c9078363c1f1e96056.jpg', -5.237820401741836), ('/home/ma02526/ResNet/base/scrapped/furor/5dabcf21f78d1700db84e810cc6c2d718a459ade.jpg', -5.545028077513781), ('/home/ma02526/ResNet/base/scrapped/elo/2acb9287d45f188348a2058f1bc509b21de3dcff.jpg', -5.600778273837401)]
# Extracting image feature...
# Extracting image feature Done. Time: 0.241 sec
# Doing naive query...
# Doing naive query Done. Time: 0.002 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/elo/c9ac6076c03b9d34136cf2ed5854e98037f64956.jpg', -3.686623468427968), ('/home/ma02526/ResNet/base/scrapped/elo/06a7cace70f8b9c5a8097212742238efad7550a6.jpg', -4.723876742949824), ('/home/ma02526/ResNet/base/scrapped/elo/aa0d21fe3d3bc84bf55fe9bb3f106e7883d4143f.jpg', -5.196476525986745), ('/home/ma02526/ResNet/base/scrapped/elo/d617b11e08332c6750a65b337e187aecd065fa3a.jpg', -5.574842554673792), ('/home/ma02526/ResNet/base/scrapped/furor/9293f81e7066cba7484100e839515b0059795712.jpg', -5.903276125600267)]
# Extracting image feature...
# Extracting image feature Done. Time: 0.137 sec
# Doing naive query...
# Doing naive query Done. Time: 0.001 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped
extractor = load_test_model()

deep_feats, color_feats, labels = load_feat_db(custom=True)

for example in examples:
    f = dump_single_feature(example, extractor, custom=True)

    if any(list(map(lambda x: x is None, f))):
        print("Input feature is None")
        exit()

    result = naive_query(f, deep_feats, color_feats, labels, 5)

    print("Naive query result:", result)
    visualize(example, result)
# Out:
# Loading model...
# Loading model freeze=False/lr=0.001/29_epochs
# Loading model Done. Time: 0.434 sec
# Loading feature database...
# Loading feature database Done. Time: 0.001 sec
# Extracting image feature...
# img_path: /home/ma02526/ResNet/base/hu_men/IMG_20200120_145822.jpg
# Custom: True
# Extracting image feature Done. Time: 0.199 sec
# Doing naive query...
# Doing naive query Done. Time: 0.000 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/furor/77906fcf947f40b7e79769de4fd9086f60cae4ba.jpg', -4.29264045424013), ('/home/ma02526/ResNet/base/scrapped/furor/ee1eb2fa967b8787b8a96b234cd95a0676dfe48c.jpg', -4.334972853662564), ('/home/ma02526/ResNet/base/scrapped/furor/75dbe92ab170f8c4c9ecbd169bea2c5f5dbd83d9.jpg', -4.352850080939946), ('/home/ma02526/ResNet/base/scrapped/furor/1a639e31574257c68cece92c3340f3e414223eb7.jpg', -4.604305490206158), ('/home/ma02526/ResNet/base/scrapped/furor/907f6c550c1ce11d9fe856d6aaad6fd0bc4e041f.jpg', -5.0528962789202705)]
# Extracting image feature...
# img_path: /home/ma02526/ResNet/base/hu_men/IMG_20200130_152400.jpg
# Custom: True
# Extracting image feature Done. Time: 0.168 sec
# Doing naive query...
# Doing naive query Done. Time: 0.001 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/furor/8cf93e26c16dc39b873c16efdb109cce416be9f3.jpg', -4.95686575698596), ('/home/ma02526/ResNet/base/scrapped/furor/cf5c25975980afee5ec3c460ac42746a042725af.jpg', -5.862417108513879), ('/home/ma02526/ResNet/base/scrapped/furor/d39bbba57e7e9e42c9c9d8b4beec19233528d76f.jpg', -6.178292590332936), ('/home/ma02526/ResNet/base/scrapped/furor/5ae74d8204d3542d999d5e9954f5fc410f148cb9.jpg', -6.749654393736801), ('/home/ma02526/ResNet/base/scrapped/furor/4eab4f247599b9f7bfd25eda7bd85dd561c7f5ec.jpg', -7.0927704521352775)]
# Extracting image feature...
# img_path: /home/ma02526/ResNet/base/hu_men/IMG_20200120_145759.jpg
# Custom: True
# Extracting image feature Done. Time: 0.164 sec
# Doing naive query...
# Doing naive query Done. Time: 0.001 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/furor/73789a68d2efa8641dde3dabfee71ffa95b23e13.jpg', -5.132003741192364), ('/home/ma02526/ResNet/base/scrapped/furor/e58685ad19decba1a64a021ddd61c958f0d37f3e.jpg', -5.145450837892745), ('/home/ma02526/ResNet/base/scrapped/furor/91e978f68528d07f7198e4c9078363c1f1e96056.jpg', -5.237820401741836), ('/home/ma02526/ResNet/base/scrapped/furor/5dabcf21f78d1700db84e810cc6c2d718a459ade.jpg', -5.545028077513781), ('/home/ma02526/ResNet/base/scrapped/furor/eb6201abd3876d317371950c322465ade3f1be2c.jpg', -5.603521900082277)]
# Extracting image feature...
# img_path: /home/ma02526/ResNet/base/hu_men/IMG_20200130_122739.jpg
# Custom: True
# Extracting image feature Done. Time: 0.165 sec
# Doing naive query...
# Doing naive query Done. Time: 0.001 sec
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/furor/eb809ca432edac18ded7a0bdfa0ece3d1403345f.jpg', -4.583531826980845), ('/home/ma02526/ResNet/base/scrapped/furor/bf5206b35a29802d44a8a7e09b61226da69862ef.jpg', -5.097552097274982), ('/home/ma02526/ResNet/base/scrapped/furor/ec26d9fb411a1e85d7d772f86879a241b9af3bab.jpg', -5.7287381741533405), ('/home/ma02526/ResNet/base/scrapped/furor/447e2787123d8c7fc1ec2f1f2e1bfd5758861d45.jpg', -5.778715613016689), ('/home/ma02526/ResNet/base/scrapped/jdot/b079081f150cdb24093376c4210ebdcee7cafe38.jpg', -5.996008475232437)]
# Extracting image feature...
# img_path: /home/ma02526/ResNet/base
# Naive query result: [('/home/ma02526/ResNet/base/scrapped/jdot/9265f20c114058ee81cdc51d83eb2583234ce489.jpg', -5.243751323545599), ('/home/ma02526/ResNet/base/scrapped/jdot/60793386dad1564bef298e26c140a53a7a2445f1.jpg', -5.431119484093491), ('/home/ma02526/ResNet/base/scrapped/jdot/422a7480fba11617b147a1735146ff08b22f6d4a.jpg', -5.495985655845783), ('/home/ma02526/ResNet/base/scrapped/jdot/e654f224abce4a8c4792b5889be7853204082573.jpg', -5.519491697189201), ('/home/ma02526/ResNet/base/scrapped/jdot/da698140f30d780d012edf493bc7ec418930818e.jpg', -5.529224638161653)]

# %%
from net import *

INTER_DIM = 512
CATEGORIES = 20
DUMPED_MODEL = "model_10_final.pth.tar"

f_model(freeze_param=False, inter_dim=INTER_DIM, num_classes=CATEGORIES, model_path=DUMPED_MODEL)
# Out:
# Loading model model_10_final.pth.tar
# f_model(
#   (backbone): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (avg_pooling): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=20, bias=True)
# )

# %%
from retrieval import *
load_feat_db(custom=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:220: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Loading feature database...
# Loading feature database Done. Time: 2.079 sec
# (array([[ 0.7963941 , -0.16327731,  0.5005752 , ...,  0.00348724,
#          -0.01936189, -0.13899098],
#         [ 0.4721783 , -0.14658882,  0.11951138, ...,  0.00857361,
#           0.07727434,  0.00837347],
#         [-0.37405765,  0.11140244, -0.46851936, ..., -0.18382262,
#           0.19089377,  0.1422693 ],
#         ...,
#         [ 0.03143787,  0.41380578, -0.43167892, ..., -0.1448812 ,
#           0.7498995 , -0.5666169 ],
#         [ 0.5645923 ,  0.4655726 , -0.21555622, ..., -0.01802251,
#           0.5896938 , -0.40011552],
#         [ 0.15612942, -0.1948817 ,  0.3831291 , ..., -0.09387633,
#          -0.13536413, -0.114146  ]], dtype=float32),
#  array([[ 0.91488415,  0.80392444,  1.010124  , ...,  1.6851585 ,
#           0.43946248,  0.28979933],
#         [ 1.9392041 ,  0.5943625 ,  1.6660447 , ...,  2.416723  ,
#           0.79087085,  1.6521537 ],
#         [-0.17305714, -1.1172597 , -0.678355  , ..., -1.3056177 ,
#          -0.7970065 , -1.334366  ],
#         ...,
#         [-0.2391158 ,  0.4897408 , -1.4208885 , ..., -0.6175889 ,
#          -0.15316477, -0.6396666 ],
#         [ 0.9947231 ,  0.9220912 ,  0.15502253, ...,  2.2100747 ,
#           1.0716964 ,  1.7501925 ],
#         [ 1.8670938 ,  1.7387936 ,  1.8569596 , ...,  1.3728938 ,
#           1.5776037 ,  1.1665188 ]], dtype=float32),
#  ['//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/0a0696c7b8f9c84c97e916cafac11a491b2f1230.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/0ad8953502aa99550cb26556560eb64fface5db7.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/0bbbcba93098a2a8cea59e3cc531685efc30e2ed.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/0d615c7c56e76fdf84e9b48191240755f4cc3804.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/0dbc2f21435c0e1cfc8b3f883d6c47df464e4e5b.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/0df6793aa25b13e2e51b70712dc6f74c5315159f.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/0ec9cddb6910c4bba113679432cf48c598b77969.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/1b84c450431041a7d85b827c3c2fb5467cb504a6.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/1d1e47e53b360bedb46a49382222ca1b693dc24e.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/1d91c48fa8f899a570db6904b7adc5b463eb85b5.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/2aa032fee6c7c26c2a9ee33e485a1ed073e770e5.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/2bf319dac8f05b775f651cc602b733134610bb37.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/2f1a88faa0112ca51d8f320b935f6bfc9c05829d.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot/4e359672c99f2c6da4f1c699e6eaa2f4a7066597.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/jdot
jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/furor/fd942ec06e7ea80a5a4dbe4c855a065fa6287134.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/furor/fe8758d83ed16cc143d052757eb984b41da109a5.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/furor/ff4fe46796ba0714ebe9d0f808370cbbcf82eaf7.jpg',
#   '//content/drive/My Drive/Deep Fashion Retrieval/base/scrapped/furor/ffd1148852b11ea9c62b6248cea4528d8ca24af4.jpg'])

# %%
from torchvision import datasets, models, transforms
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image

import torch

CROP_SIZE = 224

data_transform_test = transforms.Compose([
    transforms.Resize(CROP_SIZE),
    transforms.CenterCrop(CROP_SIZE)
    # transforms.ToTensor(),
    # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

path = '/content/drive/My Drive/Deep Fashion Retrieval/base/hu_men/IMG_20200120_145822.jpg'

# from read_crop in data.py
with open(path, 'rb') as f:
            with Image.open(f) as img:
                img = img.convert('RGB')
                x1, y1, x2, y2 = 257, 823, 1449, 2488
                if x1 < x2 <= img.size[0] and y1 < y2 <= img.size[1]:
                    img = img.crop((x1, y1, x2, y2))

plt.imshow(img)

# %%
def read_lines(path):
        with open(path) as fin:
            lines = fin.readlines()[2:]
            lines = list(filter(lambda x: len(x) > 0, lines))
            pairs = list(map(lambda x: x.strip().split(), lines))
        return pairs

def read_bbox():
        list_bbox = '/content/drive/My Drive/Deep Fashion Retrieval/base/list_bbox_custom.txt'
        pairs = read_lines(list_bbox)
        bbox = dict()
        for k, x1, y1, x2, y2 in pairs:
            bbox[k] = [x1, y1, x2, y2]
        return bbox

# print(read_lines('/content/drive/My Drive/Deep Fashion Retrieval/base/list_bbox_custom'))
print(read_bbox()['IMG_20200120_145822.jpg'])
# Out:
# ['257', '823', '1449', '2488']

# %%
# Test 20 cat model
from train import test
test(0, full=True)
# Out:
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/torchvision/transforms/transforms.py:210: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/torchvision/transforms/transforms.py:697: UserWarning: The use of the transforms.RandomSizedCrop transform is deprecated, please use transforms.RandomResizedCrop instead.
#   warnings.warn("The use of the transforms.RandomSizedCrop transform is deprecated, " +
# /home/ma02526/ResNet/deep-fashion-retrieval/train.py:212: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   data, target = Variable(data, volatile=True), Variable(target)
# Loading model model_10_final.pth.tar
# Loading model model_10_final.pth.tar
#
# Test set: Average loss: 1.1550
# Top 1 Accuracy: 24434/38784 (63%)
# Top 3 Accuracy: 33849/38784 (87%)
# Top 5 Accuracy: 36783/38784 (95%)

# %%
# Test 20 cat model in-shop. Only on tops
from in_shop_eval import eval
acc_dict = eval(list(range(1, 51)))
acc_dict
# Out:
# Extracting features of in-shop test images.
# 0 / 7901
# 0 / 8883
# n = 1. Accuracy = 54.52%.
# n = 2. Accuracy = 65.83%.
# n = 3. Accuracy = 71.18%.
# n = 4. Accuracy = 74.73%.
# n = 5. Accuracy = 77.58%.
# n = 6. Accuracy = 79.52%.
# n = 7. Accuracy = 81.14%.
# n = 8. Accuracy = 82.34%.
# n = 9. Accuracy = 83.34%.
# n = 10. Accuracy = 84.24%.
# n = 11. Accuracy = 85.13%.
# n = 12. Accuracy = 85.76%.
# n = 13. Accuracy = 86.45%.
# n = 14. Accuracy = 87.10%.
# n = 15. Accuracy = 87.57%.
# n = 16. Accuracy = 88.03%.
# n = 17. Accuracy = 88.39%.
# n = 18. Accuracy = 88.83%.
# n = 19. Accuracy = 89.20%.
# n = 20. Accuracy = 89.63%.
# n = 21. Accuracy = 89.98%.
# n = 22. Accuracy = 90.21%.
# n = 23. Accuracy = 90.39%.
# n = 24. Accuracy = 90.67%.
# n = 25. Accuracy = 90.83%.
# n = 26. Accuracy = 91.02%.
# n = 27. Accuracy = 91.24%.
# n = 28. Accuracy = 91.48%.
# n = 29. Accuracy = 91.70%.
# n = 30. Accuracy = 91.88%.
# n = 31. Accuracy = 92.09%.
# n = 32. Accuracy = 92.29%.
# n = 33. Accuracy = 92.46%.
# n = 34. Accuracy = 92.64%.
# n = 35. Accuracy = 92.83%.
# n = 36. Accuracy = 92.95%.
# n = 37. Accuracy = 93.08%.
# n = 38. Accuracy = 93.20%.
# n = 39. Accuracy = 93.30%.
# n = 40. Accuracy = 93.44%.
# n = 41. Accuracy = 93.53%.
# n = 42. Accuracy = 93.64%.
# n = 43. Accuracy = 93.75%.
# n = 44. Accuracy = 93.90%.
# n = 45. Accuracy = 93.99%.
# n = 46. Accuracy = 94.12%.
# n = 47. Accuracy = 94.26%.
# n = 48. Accuracy = 94.37%.
# n = 49. Accuracy = 94.47%.
# n = 50. Accuracy = 94.60%.
# 100%|██████████| 8883/8883 [01:37<00:00, 91.35it/s]
# {1: 54.51986941348643,
#  2: 65.83361476978499,
#  3: 71.18090735112011,
#  4: 74.72700664190026,
#  5: 77.57514353259035,
#  6: 79.52268377800293,
#  7: 81.14375773950242,
#  8: 82.3370482944951,
#  9: 83.33896206236632,
#  10: 84.23955870764381,
#  11: 85.12889789485534,
#  12: 85.75931554654959,
#  13: 86.44602048857368,
#  14: 87.09895305639986,
#  15: 87.57176629517055,
#  16: 88.03332207587526,
#  17: 88.39356073398626,
#  18: 88.83260159855905,
#  19: 89.20409771473601,
#  20: 89.63188112124281,
#  21: 89.98086232128786,
#  22: 90.20601148260722,
#  23: 90.38613081166272,
#  24: 90.66756726331194,
#  25: 90.8251716762355,
#  26: 91.01654846335697,
#  27: 91.24169762467635,
#  28: 91.47810424406168,
#  29: 91.70325340538106,
#  30: 91.88337273443656,
#  31: 92.086006979624,
#  32: 92.28864122481144,
#  33: 92.45750309580096,
#  34: 92.63762242485647,
#  35: 92.82899921197793,
#  36: 92.9528312507036,
#  37: 93.07666328942925,
#  38: 93.2004953281549,
#  39: 93.30181245074863,
#  40: 93.43690194754024,
#  41: 93.52696161206799,
#  42: 93.63953619272768,
#  43: 93.75211077338736,
#  44: 93.89845772824496,
#  45: 93.9885173927727,
#  46: 94.12360688956434,
#  47: 94.25869638635595,
#  48: 94.37127096701565,
#  49: 94.47258808960936,
#  50: 94.59642012833503}

# %%
# Test 20 cat model in-shop. On entire test set
from in_shop_eval import eval
acc_dict = eval(list(range(1, 51)))
acc_dict
# Out:
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/torchvision/transforms/transforms.py:210: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# 100%|██████████| 14218/14218 [04:28<00:00, 52.98it/s]
# Loading model model_10_final.pth.tar
# Extracting features of in-shop test images.
# 0 / 12612
# 0 / 14218
# n = 1. Accuracy = 52.72%.
# n = 2. Accuracy = 63.19%.
# n = 3. Accuracy = 68.58%.
# n = 4. Accuracy = 71.92%.
# n = 5. Accuracy = 74.37%.
# n = 6. Accuracy = 76.38%.
# n = 7. Accuracy = 78.06%.
# n = 8. Accuracy = 79.30%.
# n = 9. Accuracy = 80.33%.
# n = 10. Accuracy = 81.21%.
# n = 11. Accuracy = 82.09%.
# n = 12. Accuracy = 82.87%.
# n = 13. Accuracy = 83.43%.
# n = 14. Accuracy = 84.02%.
# n = 15. Accuracy = 84.53%.
# n = 16. Accuracy = 85.03%.
# n = 17. Accuracy = 85.46%.
# n = 18. Accuracy = 85.81%.
# n = 19. Accuracy = 86.22%.
# n = 20. Accuracy = 86.59%.
# n = 21. Accuracy = 87.01%.
# n = 22. Accuracy = 87.30%.
# n = 23. Accuracy = 87.61%.
# n = 24. Accuracy = 87.97%.
# n = 25. Accuracy = 88.17%.
# n = 26. Accuracy = 88.46%.
# n = 27. Accuracy = 88.60%.
# n = 28. Accuracy = 88.87%.
# n = 29. Accuracy = 89.06%.
# n = 30. Accuracy = 89.30%.
# n = 31. Accuracy = 89.52%.
# n = 32. Accuracy = 89.76%.
# n = 33. Accuracy = 89.91%.
# n = 34. Accuracy = 90.06%.
# n = 35. Accuracy = 90.25%.
# n = 36. Accuracy = 90.41%.
# n = 37. Accuracy = 90.56%.
# n = 38. Accuracy = 90.69%.
# n = 39. Accuracy = 90.87%.
# n = 40. Accuracy = 91.06%.
# n = 41. Accuracy = 91.19%.
# n = 42. Accuracy = 91.30%.
# n = 43. Accuracy = 91.41%.
# n = 44. Accuracy = 91.52%.
# n = 45. Accuracy = 91.63%.
# n = 46. Accuracy = 91.73%.
# n = 47. Accuracy = 91.82%.
# n = 48. Accuracy = 91.90%.
# n = 49. Accuracy = 92.04%.
# n = 50. Accuracy = 92.16%.
# {1: 52.72190181460121,
#  2: 63.19454212969475,
#  3: 68.57504571669715,
#  4: 71.92291461527641,
#  5: 74.37051624701083,
#  6: 76.37501758334506,
#  7: 78.05598537065691,
#  8: 79.30088620059081,
#  9: 80.33478688985792,
#  10: 81.20692080461387,
#  11: 82.09312139541426,
#  12: 82.86678857785905,
#  13: 83.42945561963708,
#  14: 84.02025601350401,
#  15: 84.53368968912646,
#  16: 85.02602335068224,
#  17: 85.45505697003797,
#  18: 85.81375720917147,
#  19: 86.22169081446054,
#  20: 86.59445772963849,
#  21: 87.00942467294979,
#  22: 87.29779153186102,
#  23: 87.60725840483894,
#  24: 87.96595864397243,
#  25: 88.16992544661696,
#  26: 88.4582923055282,
#  27: 88.59895906597272,
#  28: 88.86622591081728,
#  29: 89.06315937543958,
#  30: 89.29525953017303,
#  31: 89.52032634688423,
#  32: 89.75945983963989,
#  33: 89.91419327612886,
#  34: 90.06189337459558,
#  35: 90.25179350119566,
#  36: 90.40652693768463,
#  37: 90.56126037417359,
#  38: 90.68786045857364,
#  39: 90.87072724715149,
#  40: 91.06062737375157,
#  41: 91.19426079617386,
#  42: 91.29976086650724,
#  43: 91.40526093684062,
#  44: 91.51779434519624,
#  45: 91.63032775355184,
#  46: 91.72879448586299,
#  47: 91.82022788015192,
#  48: 91.89759459839641,
#  49: 92.0382613588409,
#  50: 92.16486144324097}

# %%
# Test 20 cat model in-shop. On entire test set
from in_shop_eval import eval
acc_dict = eval(list(range(1, 51)))
acc_dict
# Out:
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/torchvision/transforms/transforms.py:210: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# 100%|██████████| 14218/14218 [04:27<00:00, 53.15it/s]
# Loading model model_10_final.pth.tar
# Extracting features of in-shop test images.
# 0 / 12612
# 0 / 14218
# n = 1. Accuracy = 52.72%.
# n = 2. Accuracy = 63.19%.
# n = 3. Accuracy = 68.58%.
# n = 4. Accuracy = 71.92%.
# n = 5. Accuracy = 74.37%.
# n = 6. Accuracy = 76.38%.
# n = 7. Accuracy = 78.06%.
# n = 8. Accuracy = 79.30%.
# n = 9. Accuracy = 80.33%.
# n = 10. Accuracy = 81.21%.
# n = 11. Accuracy = 82.09%.
# n = 12. Accuracy = 82.87%.
# n = 13. Accuracy = 83.43%.
# n = 14. Accuracy = 84.02%.
# n = 15. Accuracy = 84.53%.
# n = 16. Accuracy = 85.03%.
# n = 17. Accuracy = 85.46%.
# n = 18. Accuracy = 85.81%.
# n = 19. Accuracy = 86.22%.
# n = 20. Accuracy = 86.59%.
# n = 21. Accuracy = 87.01%.
# n = 22. Accuracy = 87.30%.
# n = 23. Accuracy = 87.61%.
# n = 24. Accuracy = 87.97%.
# n = 25. Accuracy = 88.17%.
# n = 26. Accuracy = 88.46%.
# n = 27. Accuracy = 88.60%.
# n = 28. Accuracy = 88.87%.
# n = 29. Accuracy = 89.06%.
# n = 30. Accuracy = 89.30%.
# n = 31. Accuracy = 89.52%.
# n = 32. Accuracy = 89.76%.
# n = 33. Accuracy = 89.91%.
# n = 34. Accuracy = 90.06%.
# n = 35. Accuracy = 90.25%.
# n = 36. Accuracy = 90.41%.
# n = 37. Accuracy = 90.56%.
# n = 38. Accuracy = 90.69%.
# n = 39. Accuracy = 90.87%.
# n = 40. Accuracy = 91.06%.
# n = 41. Accuracy = 91.19%.
# n = 42. Accuracy = 91.30%.
# n = 43. Accuracy = 91.41%.
# n = 44. Accuracy = 91.52%.
# n = 45. Accuracy = 91.63%.
# n = 46. Accuracy = 91.73%.
# n = 47. Accuracy = 91.82%.
# n = 48. Accuracy = 91.90%.
# n = 49. Accuracy = 92.04%.
# n = 50. Accuracy = 92.16%.
# {1: 52.72190181460121,
#  2: 63.19454212969475,
#  3: 68.57504571669715,
#  4: 71.92291461527641,
#  5: 74.37051624701083,
#  6: 76.37501758334506,
#  7: 78.05598537065691,
#  8: 79.30088620059081,
#  9: 80.33478688985792,
#  10: 81.20692080461387,
#  11: 82.09312139541426,
#  12: 82.86678857785905,
#  13: 83.42945561963708,
#  14: 84.02025601350401,
#  15: 84.53368968912646,
#  16: 85.02602335068224,
#  17: 85.45505697003797,
#  18: 85.81375720917147,
#  19: 86.22169081446054,
#  20: 86.59445772963849,
#  21: 87.00942467294979,
#  22: 87.29779153186102,
#  23: 87.60725840483894,
#  24: 87.96595864397243,
#  25: 88.16992544661696,
#  26: 88.4582923055282,
#  27: 88.59895906597272,
#  28: 88.86622591081728,
#  29: 89.06315937543958,
#  30: 89.29525953017303,
#  31: 89.52032634688423,
#  32: 89.75945983963989,
#  33: 89.91419327612886,
#  34: 90.06189337459558,
#  35: 90.25179350119566,
#  36: 90.40652693768463,
#  37: 90.56126037417359,
#  38: 90.68786045857364,
#  39: 90.87072724715149,
#  40: 91.06062737375157,
#  41: 91.19426079617386,
#  42: 91.29976086650724,
#  43: 91.40526093684062,
#  44: 91.51779434519624,
#  45: 91.63032775355184,
#  46: 91.72879448586299,
#  47: 91.82022788015192,
#  48: 91.89759459839641,
#  49: 92.0382613588409,
#  50: 92.16486144324097}

# %%
# # plot accuracy of top-k in-shop image retrieval
# from matplotlib import pyplot as plt
#
# results = [0.6150662251655629, 0.7110927152317881, 0.7677980132450332, 0.8087748344370861, 0.8158112582781457, 0.8385761589403974, 0.8576158940397351, 0.8667218543046358, 0.8758278145695364, 0.882864238410596, 0.8836920529801324, 0.890728476821192, 0.8911423841059603, 0.9052152317880795, 0.9168046357615894, 0.918046357615894, 0.9159768211920529, 0.9122516556291391, 0.921771523178808, 0.9283940397350994, 0.9300496688741722, 0.9279801324503312, 0.9275662251655629, 0.9317052980132451, 0.9346026490066225, 0.9391556291390728, 0.9362582781456954, 0.9416390728476821, 0.9341887417218543, 0.9399834437086093, 0.945364238410596, 0.9375, 0.9437086092715232, 0.9478476821192053, 0.9474337748344371, 0.9486754966887417, 0.9457781456953642, 0.9466059602649006, 0.953228476821192, 0.9461920529801324, 0.9577814569536424, 0.9573675496688742, 0.9466059602649006, 0.9573675496688742, 0.9528145695364238, 0.9561258278145696, 0.9540562913907285, 0.9615066225165563, 0.9577814569536424, 0.9581953642384106]
# plt.plot(results)
# plt.xlabel('Retrieved images (k=1,...,50)')
# plt.ylabel('Retrieval Accuracy')

# %%
# from in_shop_eval import eval
# results = []
#
# for n in range(2, 52):
#   results.append(eval(retrieval_top_n=n))
#   print(results)

# %%
# from matplotlib import pyplot as plt
#
# results = [0.6134105960264901, 0.7210264900662252, 0.7644867549668874, 0.8021523178807947, 0.831953642384106, 0.831953642384106, 0.8547185430463576, 0.8621688741721855, 0.8774834437086093, 0.8774834437086093, 0.8820364238410596, 0.894453642384106, 0.8990066225165563, 0.9027317880794702, 0.9048013245033113, 0.9122516556291391, 0.9097682119205298, 0.9151490066225165, 0.9234271523178808, 0.9184602649006622, 0.921771523178808, 0.9275662251655629, 0.9230132450331126, 0.9350165562913907, 0.9366721854304636, 0.9387417218543046, 0.9350165562913907, 0.9445364238410596, 0.9379139072847682, 0.9354304635761589, 0.9395695364238411, 0.9503311258278145, 0.9424668874172185, 0.9445364238410596, 0.9457781456953642, 0.9441225165562914, 0.9548841059602649, 0.9486754966887417, 0.9486754966887417, 0.9470198675496688, 0.9441225165562914, 0.953228476821192, 0.9482615894039735, 0.9552980132450332, 0.9511589403973509, 0.9606788079470199, 0.9552980132450332, 0.9552980132450332, 0.9507450331125827, 0.9627483443708609]
# plt.plot(results)
# plt.xlabel('Retrieved images (k=1,...,50)')
# plt.ylabel('Retrieval Accuracy')

# %%
# for lr=0.01/29_epochs
from in_shop_eval import eval
acc_dict = eval(list(range(1, 51)))
acc_dict
# Out:
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/torchvision/transforms/transforms.py:210: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# /home/ma02526/anaconda3/envs/deep-fashion-retrieval/lib/python3.8/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# 100%|██████████| 14218/14218 [04:29<00:00, 52.72it/s]
# Loading model freeze=False/lr=0.001/29_epochs
# Extracting features of in-shop test images.
# 0 / 12612
# 0 / 14218
# n = 1. Accuracy = 61.50%.
# n = 2. Accuracy = 71.57%.
# n = 3. Accuracy = 76.56%.
# n = 4. Accuracy = 79.46%.
# n = 5. Accuracy = 81.47%.
# n = 6. Accuracy = 83.29%.
# n = 7. Accuracy = 84.65%.
# n = 8. Accuracy = 85.67%.
# n = 9. Accuracy = 86.55%.
# n = 10. Accuracy = 87.33%.
# n = 11. Accuracy = 87.98%.
# n = 12. Accuracy = 88.58%.
# n = 13. Accuracy = 89.04%.
# n = 14. Accuracy = 89.65%.
# n = 15. Accuracy = 90.00%.
# n = 16. Accuracy = 90.32%.
# n = 17. Accuracy = 90.59%.
# n = 18. Accuracy = 90.88%.
# n = 19. Accuracy = 91.25%.
# n = 20. Accuracy = 91.51%.
# n = 21. Accuracy = 91.77%.
# n = 22. Accuracy = 91.97%.
# n = 23. Accuracy = 92.18%.
# n = 24. Accuracy = 92.32%.
# n = 25. Accuracy = 92.60%.
# n = 26. Accuracy = 92.77%.
# n = 27. Accuracy = 92.96%.
# n = 28. Accuracy = 93.14%.
# n = 29. Accuracy = 93.30%.
# n = 30. Accuracy = 93.47%.
# n = 31. Accuracy = 93.61%.
# n = 32. Accuracy = 93.72%.
# n = 33. Accuracy = 93.84%.
# n = 34. Accuracy = 93.99%.
# n = 35. Accuracy = 94.10%.
# n = 36. Accuracy = 94.15%.
# n = 37. Accuracy = 94.23%.
# n = 38. Accuracy = 94.27%.
# n = 39. Accuracy = 94.38%.
# n = 40. Accuracy = 94.44%.
# n = 41. Accuracy = 94.54%.
# n = 42. Accuracy = 94.61%.
# n = 43. Accuracy = 94.69%.
# n = 44. Accuracy = 94.75%.
# n = 45. Accuracy = 94.83%.
# n = 46. Accuracy = 94.94%.
# n = 47. Accuracy = 95.08%.
# n = 48. Accuracy = 95.14%.
# n = 49. Accuracy = 95.18%.
# n = 50. Accuracy = 95.20%.
# {1: 61.499507666338445,
#  2: 71.57124771416514,
#  3: 76.55788437192291,
#  4: 79.45561963707975,
#  5: 81.4671543114362,
#  6: 83.28878885919258,
#  7: 84.64622309748206,
#  8: 85.67309044872697,
#  9: 86.5452243634829,
#  10: 87.32592488394992,
#  11: 87.98002532001688,
#  12: 88.57785905190603,
#  13: 89.0420593613729,
#  14: 89.64692643128429,
#  15: 89.99859333239556,
#  16: 90.32212688141792,
#  17: 90.58939372626249,
#  18: 90.88479392319596,
#  19: 91.25052750035167,
#  20: 91.510761007174,
#  21: 91.77099451399634,
#  22: 91.97496131664089,
#  23: 92.1789281192854,
#  24: 92.31959487972992,
#  25: 92.60092840061893,
#  26: 92.76972851315234,
#  27: 92.95962863975242,
#  28: 93.13546209030807,
#  29: 93.30426220284147,
#  30: 93.47306231537488,
#  31: 93.60669573779717,
#  32: 93.71922914615276,
#  33: 93.83879589253058,
#  34: 93.99352932901955,
#  35: 94.09902939935293,
#  36: 94.1482627655085,
#  37: 94.23266282177522,
#  38: 94.27486284990857,
#  39: 94.38036292024195,
#  40: 94.44366296244198,
#  41: 94.5350963567309,
#  42: 94.61246307497538,
#  43: 94.68982979321986,
#  44: 94.7531298354199,
#  45: 94.83049655366436,
#  46: 94.94302996201998,
#  47: 95.07666338444226,
#  48: 95.13996342664228,
#  49: 95.17513011675341,
#  50: 95.20326346884231}

# %%
acc_dict
# Out:
# {1: 42.80489520326347,
#  2: 53.1650021100014,
#  3: 58.5736390490927,
#  4: 62.645941763961176,
#  5: 65.54367702911802,
#  6: 67.83654522436349,
#  7: 69.65114643409763,
#  8: 71.28288085525391,
#  9: 72.48558165705444,
#  10: 73.6671824447883,
#  11: 74.75734983823322,
#  12: 75.67871711914475,
#  13: 76.61415107610073,
#  14: 77.35968490645661,
#  15: 78.03488535659024,
#  16: 78.63271908847939,
#  17: 79.19538613025742,
#  18: 79.7158531439021,
#  19: 80.30665353776902,
#  20: 80.72162048108032,
#  21: 81.29132086088057,
#  22: 81.68518779012518,
#  23: 82.09312139541426,
#  24: 82.50105500070333,
#  25: 82.88788859192573,
#  26: 83.30285553523701,
#  27: 83.66155577437051,
#  28: 83.96398930932621,
#  29: 84.24532283021522,
#  30: 84.48445632297089,
#  31: 84.76578984385989,
#  32: 85.04712336474891,
#  33: 85.2932901955268,
#  34: 85.56759037839359,
#  35: 85.69419046279364,
#  36: 85.94035729357154,
#  37: 86.08102405401603,
#  38: 86.27092418061612,
#  39: 86.41862427908286,
#  40: 86.58742439161627,
#  41: 86.77732451821635,
#  42: 86.94612463074975,
#  43: 87.11492474328317,
#  44: 87.36109157406105,
#  45: 87.55099170066113,
#  46: 87.69869179912787,
#  47: 87.83935855957237,
#  48: 88.05739203826136,
#  49: 88.14179209452806,
#  50: 88.25432550288367}

# %%
from matplotlib import pyplot as plt
from config import *

plt.plot(list(acc_dict.keys()), list(acc_dict.values()),
         marker = 'o', markevery=10)
for i in (1, 10, 20, 30, 40, 50):
    plt.annotate(f"({i}, {acc_dict[i]:.1f}%)", (i, acc_dict[i]),
                 textcoords="offset points", # how to position the text
                 xytext=(0,10),
                 ha='center')

plt.title('In-shop Retrieval. LR=0.001, 29 Epochs.')
plt.xlabel('Retrieved images (k=1,...,50)')
plt.ylabel('Retrieval Accuracy')
plt.show()
plt.savefig("lr=0.001-29epochs.png")

# %%
acc_dict_new = {1: 42.80489520326347,
 2: 53.1650021100014,
 3: 58.5736390490927,
 4: 62.645941763961176,
 5: 65.54367702911802,
 6: 67.83654522436349,
 7: 69.65114643409763,
 8: 71.28288085525391,
 9: 72.48558165705444,
 10: 73.6671824447883,
 11: 74.75734983823322,
 12: 75.67871711914475,
 13: 76.61415107610073,
 14: 77.35968490645661,
 15: 78.03488535659024,
 16: 78.63271908847939,
 17: 79.19538613025742,
 18: 79.7158531439021,
 19: 80.30665353776902,
 20: 80.72162048108032,
 21: 81.29132086088057,
 22: 81.68518779012518,
 23: 82.09312139541426,
 24: 82.50105500070333,
 25: 82.88788859192573,
 26: 83.30285553523701,
 27: 83.66155577437051,
 28: 83.96398930932621,
 29: 84.24532283021522,
 30: 84.48445632297089,
 31: 84.76578984385989,
 32: 85.04712336474891,
 33: 85.2932901955268,
 34: 85.56759037839359,
 35: 85.69419046279364,
 36: 85.94035729357154,
 37: 86.08102405401603,
 38: 86.27092418061612,
 39: 86.41862427908286,
 40: 86.58742439161627,
 41: 86.77732451821635,
 42: 86.94612463074975,
 43: 87.11492474328317,
 44: 87.36109157406105,
 45: 87.55099170066113,
 46: 87.69869179912787,
 47: 87.83935855957237,
 48: 88.05739203826136,
 49: 88.14179209452806,
 50: 88.25432550288367}

# %%
acc_dict_new
# Out:
# {1: 42.80489520326347,
#  2: 53.1650021100014,
#  3: 58.5736390490927,
#  4: 62.645941763961176,
#  5: 65.54367702911802,
#  6: 67.83654522436349,
#  7: 69.65114643409763,
#  8: 71.28288085525391,
#  9: 72.48558165705444,
#  10: 73.6671824447883,
#  11: 74.75734983823322,
#  12: 75.67871711914475,
#  13: 76.61415107610073,
#  14: 77.35968490645661,
#  15: 78.03488535659024,
#  16: 78.63271908847939,
#  17: 79.19538613025742,
#  18: 79.7158531439021,
#  19: 80.30665353776902,
#  20: 80.72162048108032,
#  21: 81.29132086088057,
#  22: 81.68518779012518,
#  23: 82.09312139541426,
#  24: 82.50105500070333,
#  25: 82.88788859192573,
#  26: 83.30285553523701,
#  27: 83.66155577437051,
#  28: 83.96398930932621,
#  29: 84.24532283021522,
#  30: 84.48445632297089,
#  31: 84.76578984385989,
#  32: 85.04712336474891,
#  33: 85.2932901955268,
#  34: 85.56759037839359,
#  35: 85.69419046279364,
#  36: 85.94035729357154,
#  37: 86.08102405401603,
#  38: 86.27092418061612,
#  39: 86.41862427908286,
#  40: 86.58742439161627,
#  41: 86.77732451821635,
#  42: 86.94612463074975,
#  43: 87.11492474328317,
#  44: 87.36109157406105,
#  45: 87.55099170066113,
#  46: 87.69869179912787,
#  47: 87.83935855957237,
#  48: 88.05739203826136,
#  49: 88.14179209452806,
#  50: 88.25432550288367}

# %%
from matplotlib import pyplot as plt
from config import *

plt.plot(list(acc_dict_new.keys()), list(acc_dict_new.values()),
         marker = 'o', markevery=10, label="Experiment #1")
plt.plot(list(acc_dict.keys()), list(acc_dict.values()),
         marker = 'o', markevery=10, label="Experiment #3")
for i in (1, 10, 20, 30, 40, 50):
    plt.annotate(f"({i}, {acc_dict_new[i]:.1f}%)", (i, acc_dict_new[i]),
                 textcoords="offset points", # how to position the text
                 xytext=(0,10),
                 ha='center')
    plt.annotate(f"({i}, {acc_dict[i]:.1f}%)", (i, acc_dict[i]),
                 textcoords="offset points", # how to position the text
                 xytext=(0,10),
                 ha='center')

plt.title('Top-k In-shop Retrieval.')
plt.xlabel('Retrieved images (k=1,...,50)')
plt.ylabel('Top-k Retrieval Accuracy')
plt.legend(loc="best")
# plt.show()
plt.savefig("inshop-retrieval.png")
